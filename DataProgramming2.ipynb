# %% [markdown]
# Question1

# %%
a = 0
def b():
 global a
 a = c(a)
def c(a):
 return a + 2

# %%
b()

# %%
b()

# %%
b()

# %%
a
# Out:
# 6

# %% [markdown]
# Explanation:
# In line 2 , b() gets call which eventually calls function c(a) i.e c(0) and return value to a = 0+2 i.e 2.
# Similary In line 3 when b() gets call & the value of a is updated as a=a+2 = 2+2 = 4
# In line 4 b() function gets call and return the value to a = a+2 i.e 4+2 ( as value of a is updated to 4 in previous call) =6
# So in line 5 when a is printed then it prints the value 6 ( which gets incremented by 2 with every call of b() function in previous 3 steps.

# %% [markdown]
# Question: 2

# %%
import os
def fileLength(filename):
    try:
        fileinfo=os.stat(filename)
        #To print size of file
        print(fileinfo.st_size)
    except IOError:
        print("File",str(filename),"not found")
fileLength('DataProgramming2.ipynb')
fileLength('idterm.py')
# Out:
# 13229
# File idterm.py not found

# %% [markdown]
# Question: 3

# %%
class Marsupial(object):
  def __init__(self):
    self.lst = []

  def put_in_pouch(self, item):
    self.lst.append(item)

  def pouch_contents(self):
    return self.lst

# %%
class Kangaroo(Marsupial):
  def __init__(self,x,y):
    Marsupial.__init__(self)
    self.x = x
    self.y = y

  def jump(self,dx,dy):
    self.x += dx
    self.y += dy

  def __str__(self):
    return 'I am a Kangaroo located at coordinates ({},{})'.format(self.x,self.y)

# %%
#First Task
m = Marsupial()
m.put_in_pouch('doll')
m.put_in_pouch('firetruck')
m.put_in_pouch('kitten')
m.pouch_contents()
k = Kangaroo(0,0)
print(k)
# Out:
# I am a Kangaroo located at coordinates (0,0)

# %%
#Second Task
k.put_in_pouch('doll')
k.put_in_pouch('firetruck')
k.put_in_pouch('kitten')
k.pouch_contents()
k.jump(1,0)
k.jump(1,0)
k.jump(1,0)
print(k)
# Out:
# I am a Kangaroo located at coordinates (3,0)

# %% [markdown]
# Question: 4

# %%
def collatz(number):
    while number != 1:
        if number % 2 == 0:
            number = number // 2
            print(number)

        elif number % 2 == 1:
            number = number * 3 + 1
            print(number)

try:
    x = int(input())
    collatz(x)
#if user inputs other number than whole number then print the message to enter whole number
except ValueError:
    print('Please use whole numbers only.')
# Out:
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %% [markdown]
# Question 5

# %%
# Function to print binary number using recursion
def binary(n):
   if n < 0:
        print("Input Error: Enter Positive number only")
   elif n ==0:
        return 0
   elif n==1:
        return 1
   else:
        return ((n%2)+10*binary(n//2))

# %%
binary (0)
# Out:
# 0

# %%
binary(-1)
# Out:
# Input Error: Enter Positive number only

# %%
binary(3)
# Out:
# 11

# %%
binary(9)
# Out:
# 1001

# %% [markdown]
# Question 6

# %%
import re
from html.parser import HTMLParser

class HeadingParser(HTMLParser):
  def handle_starttag(self, tag, attrs):
   # global g
    global getHeader
    match = re.match(r'h(\d)', tag, re.I)

    if match:
      #print("-----start tag:-----", tag)
      print(match.group(1))
    
      getHeader=int(match.group(1))
        
   # For End of the tag  
  def handle_endtag(self, tag):
    match = re.match(r'h(\d)', tag, re.I)
    if match:
      #print("Encountered an end tag :", tag)
      getHeader=0



  def handle_data(self, data):
   
    if getHeader > 0:
      #tab = getH - 1
      tab = getHeader-1
      out = "\t"*tab
      print(out + data)
        
getHeader=0
infile = open('w3c.html')
content = infile.read()
infile.close()
hp = HeadingParser()
hp.feed(content)
# Out:
# 1
#
#
#
#
# W3C
#
#
#
#
#
#
#
#
# Leading the web to its full potential
#
#
# Standards
#
#
#
#
# Participate
#
#
#
#
# Membership
#
#
#
#
# About W3C
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2
# 	Site Navigation
#
#
# 3
# 		W3C
#
#
#
#
# 		Standards
#
#
# 		Participate
#
#
# 		Membership
#
#
# 		About W3C
#
#
# 		Member Home
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Skip
#
#
# 		W3C
#
# 		Â»
#
#
#
# 		About W3C
#
#
#
#
#
#
#
#
# 1
# About W3C
#
#
#
#
#
#
#
#
#
#
#
#
# 			   The World Wide Web Consortium (W3C) is an
# international community where
# Member
# organizations
# , a full-time
#
# staff
# , and the public work together to
# develop
# Web standards
# . Led by Web inventor
# and Director
# Tim Berners-Lee
#  and
# CEO
# Jeffrey Jaffe
# , W3C's mission is to
# lead the Web to its full potential.
# Contact W3C
#
# for more information.
#
#
#
#
#
#
#
# 2
#
#
#
#
# 	 W3C Mission
#
#
#
#
#
#
#
#
# 3
#
#
# 		Principles, vision, â€¦
#
#
#
#
#
#
# 		principles
# 		 - Web for all, Web on everything
#
#
# 		vision
# 		 - Web of consumers and authors, data and services, trust
#
#
#
#
#
#
# 2
#
#
#
#
# 	 Facts About W3C
#
#
#
#
#
#
#
#
# 3
#
#
# 		People, organization, revenues, process, patent policy, history, â€¦
#
#
#
#
#
#
# 		people of W3C
# 		 - Tim Berners-Lee, staff, W3C Evangelists, W3C Members
#
#
# 		organizational structure
# 		 - hosts, offices, process and patent policy, permanent groups
#
#
# 		revenue model
# 		 - W3C dues, grants, other forms of support
#
#
# 		international presence
# 		 - W3C activities span the globe, in multiple languages
#
#
# 		process
# 		 - how W3C produces standards
#
#
# 		patent policy
# 		 - community commitment to Royalty-Free standards
#
#
# 		history
# 		 - from the invention of the Web through key milestones
#
#
#
#
#
#
# 2
#
#
#
#
# 	 Press and Analysts
#
#
#
#
#
#
#
#
# 3
#
#
# 		Press releases, requests for photos and interviews, â€¦
#
#
#
#
#
#
# 		W3C press releases
#
#
#
#
# 		W3C in the press
# 		 - select links to articles and blogs about W3C
#
#
# 		interview requests
# 		 - experts on Web technology can answer your questions
#
#
# 		photo requests
#
#
#
#
# 		speaker requests
# 		 - we will try to connect you with a speaker for your next conference
#
#
#
#
#
#
# 2
#
#
#
#
# 	 Sponsorship and Donations
#
#
#
#
#
#
#
#
# 3
#
#
# 		Support for W3C operations, validator service, â€¦
#
#
#
#
#
#
# 		organization sponsor
# 		 - how organizations and individuals that benefit greatly from the Web can support operations
#
#
# 		event sponsor
# 		 - reach with W3C's international audience of technology influencers
#
#
#
# 		web for all sponsor
# 		 - demonstrate leadership in social responsibility to make the Web available to all people
#
#
#
# 		developer sponsor
# 		 -  help W3C provide tools and educational materials to the international developer community
#
#
#
#
# 		validator sponsorship
# 		 - help W3C continue to provide this free service
#
#
#
#
#
#
# 2
#
#
#
#
# 	 Jobs and Fellowships
#
#
#
#
#
#
#
#
# 3
#
#
# 		Employment opportunities, fellows, â€¦
#
#
#
#
#
#
# 		open positions
# 		 - contribute as part of the W3C Team
#
#
# 		fellows
# 		 - Member employees integrated as staff
#
#
#
#
#
#
#
#
#
# 2
# 	Questions About W3C or the Web?
#
#
#
# 	Please consult the
# 	Help and FAQ
#
# for answers to questions such as:
#
#
#
#
#
# 	What does W3C do?
#
#
#
#
# 	How is W3C funded?
#
#
#
#
# 	Is W3C sending me spam?
#
#
#
#
# 	What is the difference between the Web and the Internet?
#
#
#
#
#
#
#
#
#
# 2
# 	Quick Links
#
#
#
#
# 	Contact
#
#
#
#
# 	Staff
#
#
#
#
# 	Help and FAQ
#
#
#
#
# 	Systems Status (outages)
#
#
#
#
#
# 2
# 	Video on Web Accessibility and W3C Standards
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2
# 	Video on Web Standards
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2
# 	Video on W3C
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2
# 	Footer Navigation
#
#
#
#
# 3
# 		Navigation
#
#
#
#
# 		Home
#
#
#
#
# 		Standards
#
#
#
#
# 		Participate
#
#
#
#
# 		Membership
#
#
#
#
# 		About W3C
#
#
#
#
#
#
#
#
# 3
# 		Contact W3C
#
#
#
#
# 		Contact
#
#
#
#
# 		Help and FAQ
#
#
#
#
# 		Sponsor / Donate
#
#
#
#
# 		Site Map
#
#
#
#
#
#
# 		Feedback
#
#
#
#
#
#
#
#
# 3
# 		W3C Updates
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Copyright Â© 2021 W3C
# 		Â®
# 		 (
#
#
# 		MIT
#
#
# 		,
#
#
# 		 ERCIM
#
#
# 		,
# 		Keio
# 		,
# 		Beihang
# 		)
# 		Usage policies apply
# 		.
#
#
#
#
#
#
# 		<!---->

# %% [markdown]
# Question 7

# %%
#In anaconda to install : pip3 install httplib2 --upgrade
# Beautifulsoup to pull data of html
from bs4 import BeautifulSoup, SoupStrainer
import httplib2
#httplib2 to access Web resources

def getLinks(url):
    res = []
    http = httplib2.Http()
    status, response = http.request(url)

    for link in BeautifulSoup(response, parse_only=SoupStrainer('a'), features="html.parser"):
        if link.has_attr('href'):
            if link['href'][:5] == "http:" or link['href'][:5] == "https":
                res.append(link['href'])

    return res
#This getLinks (url) funtion simply finds all the <a> tags in the provided page and gets their corresponding url.

# %%
#Now, the webdir function: 
def webdir(url, depth, indent):
    print(indent*" " + url)
    if depth == 0:
        return

    for i in getLinks(url):
        webdir(i, depth-1, indent+1)
webdir("http://reed.cs.depaul.edu/lperkovic/csc242/test1.html", 2, 0)
# Out:
# http://reed.cs.depaul.edu/lperkovic/csc242/test1.html

# %% [markdown]
# Question:9

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# Printing all words upper case
print("9a:\t")
print([x.upper() for x in words])

# Printing all words lower case
print("9b:\t")
print([x.lower() for x in words])

# Printing length of each word
print("9c:\t")
print([len(x) for x in words])

# Printing the list containing a list for every word of list words,
# where each list contains the word in uppercase and lowercase and the length of the word
print("9d:\t")
print([[x.upper(), x.lower(), len(x)] for x in words])

# Printing the list of words in list words containing 4 or more characters
print("9e:\t")
print([x for x in words if len(x)>=4])
# Out:
# 9a:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
# 9b:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# 9c:
# [3, 5, 5, 3, 5, 4, 3, 4, 3]
# 9d:
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]
# 9e:
# ['quick', 'brown', 'jumps', 'over', 'lazy']
